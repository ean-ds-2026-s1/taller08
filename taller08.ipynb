# %% [markdown]
# # Estructura de Datos
#
# ## Taller 08 - Listas de Nodos Sencillamente Encadenados
#
# Nombre del primer integrante:
#
# Nombre del segundo integrante:
#
# ---

# %% [markdown]
# En este taller vamos a trabajar con la clase departamento que ya está realizada para nosotros.
# El diagrama de clase de esta clase es el siguiente:
#
# ![Clase Departamento](https://raw.githubusercontent.com/luiscobo/poo/refs/heads/main/departamento.png)
#
# Esta clase posee los siguientes atributos:
#
# * El `nombre` del departamento.
# * `cant_municipios`: que indica cuántos municipios están dentro de ese departamento.
# * `capital`: el nombre de la capital del departamento.
# * `superficie`: El área del departamento en metros cuadrados.
# * `poblacion`: el número de personas que habitan ese departamento.
# * `densidad`: el número de personas por metro cuadrado en el departamento.
# * `indice_desarrollo_humano`: nivel del progreso y bienestar de los habitantes del departamentos.
# * `fecha_creacion`: el año en el cual el departamento fue creado.
# * `region`: la región del país donde se encuentra el departamento: Amazonía, Caribe, Andina, Pacífico u Orinoquía.
#
# A partir de esto, desarrolle los siguientes ejercicios:

# %% [markdown]
# ---
#
# ### Primero lo primero
#
# Ejecute el siguiente código para poder utilizar los noditos de la
# librería EAN.

# %%
# Ejecute este código primero antes que todo para traer la clase departamento

# !rm ean_estructuras_datos.py
# !wget https://github.com/ean-ds-2026-s1/taller08/raw/refs/heads/main/ean.py

# %% [markdown]
# ---
#
# ### Ejercicio 1: funciones externas del departamento
#
# Escriba una función externa llamada `edad_departamento` que recibe un objeto de la clase `Departamento`
# y que retorne cuántos años han pasado desde la creación del departamento hasta el año 2026.

# %%
from ean import Departamento

# Escribir la función edad_departamento

# %% [markdown]
# ---
#
# Pruebas del ejercicio 1

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, obtener_nodo_pos

# Prueba de hallar_imc
class TestEjercicio1(unittest.TestCase):
    def test_edad_departamento(self):
        lista = crear_lista_nodos_departamentos()
        self.assertEqual(98, edad_departamento(obtener_nodo_pos(lista, 0).informacion))
        self.assertEqual(59, edad_departamento(obtener_nodo_pos(lista,11).informacion))
        self.assertEqual(116, edad_departamento(obtener_nodo_pos(lista, 31).informacion))
        print("Prueba superada 👍🏼")

# ----------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio1'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 2: Los Nodos de Departamentos
#
# En este taller vamos a trabajar con una lista de departamentos a través de nodos sencillamente
# encadenados. Dado esto, defina el método `crear_nodo_departamento` que recibe un objeto de la
# clase `Departamento` llamado `depto` y proceda a crear y retornar un nuevo nodito que contenga
# el departamento recibido como parámetro.

# %%
from ean import Departamento, Nodito

# Definición de la función que crea un nodo de departamento
def crear_nodo_departamento(depto: Departamento) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del Ejercicio 2

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos

# Prueba de hallar_imc
class TestEjercicio02(unittest.TestCase):
    def test_nodo_departamento(self):
        cabeza = crear_lista_nodos_departamentos()
        nodo = crear_nodo_departamento(cabeza.informacion)
        self.assertEqual(cabeza.informacion, nodo.informacion)
        self.assertTrue(nodo.sig.es_nulo)
        self.assertEqual(type(nodo), Nodito)
        print("Prueba superada 👍🏼")


# -------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio02'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 3: Agregar un nodo al principio de la lista
#
# Vamos a tener una lista de nodos sencillamente encadenada de departamentos. Traduzca
# el siguiente algoritmo a Python que va a permitir agregar un nodo al principio de la
# lista.
#
# Esta función externa va a recibir dos parámetros: ep  el primer parámetro será la cabeza
# a una lista de noditos de departamentos y el segundo parámetro será un objeto de la clase
# departamento, que es el que vamos a agregar al principio de la lista. Esta función va a
# retornar la cabeza de la lista, pero con el nuevo nodo al principio.
#
# El algoritmo es el siguiente:
#
# ```
# nuevo-nodo = crear-nodo-departamento(depto)
# si la cabeza es nula entonces
#     asignarle a la cabeza el nuevo-nodo
# sino
#     al siguiente del nuevo-nodo asignarle la cabeza
#     asignarle a la cabeza el nuevo-nodo
# fin-si
# retornar la cabeza de la lista
# ```

# %%
from ean import Departamento, Nodito, nulo

# Función de agregar un nuevo nodo
def agregar_nodo_al_principio(cabeza: Nodito[Departamento], depto: Departamento) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del Ejercicio 3

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo

# Prueba de hallar_imc
class TestEjercicio03(unittest.TestCase):
    def test_ejercicio03(self):
        lista = crear_lista_nodos_departamentos()
        cabeza = agregar_nodo_al_principio(nulo, obtener_nodo_pos(lista, 11).informacion)
        self.assertTrue(cabeza.no_es_nulo)
        self.assertTrue(cabeza.sig.es_nulo)
        self.assertEqual("Valledupar", cabeza.informacion.capital)

        cabeza = agregar_nodo_al_principio(cabeza, obtener_nodo_pos(lista, 28).informacion)
        self.assertTrue(cabeza.no_es_nulo)
        self.assertEqual("Sincelejo", cabeza.informacion.capital)

        actual: Nodito[Departamento] = cabeza.sig
        self.assertTrue(actual.no_es_nulo)
        self.assertTrue(actual.sig.es_nulo)
        self.assertEqual("Valledupar", actual.informacion.capital)

        cabeza = agregar_nodo_al_principio(cabeza, obtener_nodo_pos(lista, 0).informacion)
        self.assertTrue(cabeza.no_es_nulo)
        self.assertTrue(cabeza.sig.no_es_nulo)
        self.assertTrue(cabeza.sig.sig.no_es_nulo)
        self.assertTrue(cabeza.sig.sig.sig.es_nulo)

        actual = cabeza
        self.assertEqual("Leticia", actual.informacion.capital)
        actual = actual.sig
        self.assertEqual("Sincelejo", actual.informacion.capital)
        actual = actual.sig
        self.assertEqual("Valledupar", actual.informacion.capital)
        actual = actual.sig
        self.assertTrue(actual.es_nulo)

        print("Prueba superada 👍🏼")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio03'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 4: Agregar un nodo al final de la lista
#
# En esta ocasión vamos a tomar un departamento y lo vamos a colocar en un nodo
# al final de la lista de nodos sencillamente encadenados.
#
# ![Insertar al Final](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEicoEOkfaRydyGrcGk0ifxpk1VRya46syPXDY2SsA-ZkyWUafeYx7qdmxxslbR5f4QYo4f-M9PTHOZwajShObqAgqDbK8qSqkihuIqwxPmPNgwHChxbC7tZIahC_EqH38m-97VmWNnTHGc/s1600/insert+node+at+tail+of+linked+list.jpg)
#
# Escriba una función externa llamada `agregar_nodo_al_final` que reciba dos parámetros: el primer parámetro
# es la cabeza de una lista de noditos de departamentos llamado `cabeza`, y el segundo parámetro es un objeto
# de la clase `Departamento` llamado `depto` y agregará un nuevo nodo con ese departamento al final de la
# lista de nodos y retornará la cabeza al final. Para realizar esta tarea vamos a seguir el siguiente algoritmo:
#
# ```
# nuevo-nodo = crear-nodo-departamento(depto)
# si la cabeza es nula entonces
#   a la cabeza asígnele el nuevo-nodo
# sino
#   a una variable act asignarle la cabeza
#   mientras que el siguiente del nodo act no sea nulo
#       avanzar act al siguiente de act
#   fin-mientras-que
#   al siguiente del nodo act asignarle el nuevo-nodo
# fin-si
# retorne la cabeza
# ```

# %%
from ean import Nodito, Departamento

# Ejercicio 4: Agregar al final

def agregar_nodo_al_final(cabeza: Nodito[Departamento], depto: Departamento) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del Ejercicio 4

# %%
import unittest
from ean import crear_lista_nodos_departamentos, nulo

# Prueba del ejercicio 4
class TestEjercicio04(unittest.TestCase):
    def assertEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertTrue(nodo1.es_nulo)

    def assertNoEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertFalse(nodo1.es_nulo)

    def test_ejercicio04(self):
        lista = crear_lista_nodos_departamentos()

        cabeza: Nodito[Departamento] = nulo
        cabeza = agregar_nodo_al_final(cabeza, obtener_nodo_pos(lista, 11).informacion)
        self.assertNoEsNulo(cabeza)
        self.assertEsNulo(cabeza.sig)
        self.assertEqual("Valledupar", cabeza.informacion.capital)

        cabeza = agregar_nodo_al_final(cabeza, obtener_nodo_pos(lista, 28).informacion)
        self.assertNoEsNulo(cabeza)
        self.assertNoEsNulo(cabeza.sig)
        actual: Nodito[Departamento] = cabeza
        self.assertEqual("Valledupar", actual.informacion.capital)
        actual = actual.sig
        self.assertNoEsNulo(actual)
        self.assertEsNulo(actual.sig)
        self.assertEqual("Sincelejo", actual.informacion.capital)

        cabeza = agregar_nodo_al_final(cabeza, obtener_nodo_pos(lista, 0).informacion)
        self.assertNoEsNulo(cabeza)
        self.assertNoEsNulo(cabeza.sig)
        self.assertNoEsNulo(cabeza.sig.sig)
        self.assertEsNulo(cabeza.sig.sig.sig)

        actual = cabeza
        self.assertEqual("Valledupar", actual.informacion.capital)
        actual = actual.sig
        self.assertEqual("Sincelejo", actual.informacion.capital)
        actual = actual.sig
        self.assertEqual("Leticia", actual.informacion.capital)
        actual = actual.sig
        self.assertEsNulo(actual)

        print("Prueba superada 👍🏼")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio04'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 5: Agregar un elemento en una posición
#
# Ahora vamos a agregar un elemento en una posición o índice dado de la
# lista de nodos. Estas posiciones son números enteros que van desde cero
# en adelante.
#
# ![Insertar nodo](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEg6b1fIBATk483P6x6kC7hHeEKQx6FXkAHXT6EBdi_hCD0y-M6xHO2Ud_BC0PbJyWX3uuJ7JuzNqXJ6RPGQUZGRjI2xgLnDS6B0OYCbAO0NZs4VqRUIuFIlf1-odCBlJEZNIPXNIW-_iBs/s1600/insert-node-after-given-node-of-linked-list.jpg)
#
# El método que vamos a escribir se llama `agregar_nodo_en_posicion` y va a recibir tres parámetros. El primer parámetro se llama
# `cabeza` y es el primer nodito de una lista de noditos de departamentos; el segundo parámetro será un objeto de la clase Departamento
# llamado `depto`; el tercer parámetro es la posición donde vamos a guardar el nuevo nodo, este es un dato de tipo `int` llamado
# `posicion`. El algoritmo para insertar en una posición es el siguiente:
#
# ```
# si la cabeza es nula o la posición es cero entonces
#   retornar agregar el depto al principio de la lista
# sino
#   nuevo-nodo = crear-nodo-departamento(depto)
#   haga actual igual a la cabeza
#   haga i igual a 1
#   mientras que i sea inferior a la posicion y el siguiente del nodo actual no sea nulo:
#     avanzar actual al siguiente del actual
#     súmele 1 a i
#   fin-mientras-que
#   haga al siguiente del nodo igual al siguiente de actual
#   haga al siguiente del actual igual al nodo
#   retornar la cabeza
# fin-si
# retornar la cabeza
# ```
#
# Ahora escriba y prueba el algoritmo.

# %%
from ean import Nodito, Departamento, nulo

# Ejercicio 5: Agregar nodo en posición
def agregar_nodo_en_posicion(cabeza: Nodito[Departamento], depto: Departamento, posicion: int) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del Ejercicio 5

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo, obtener_nodo_pos

# Prueba de hallar_imc
class TestEjercicio05(unittest.TestCase):
    def assertEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertTrue(nodo1.es_nulo)

    def assertNoEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertFalse(nodo1.es_nulo)

    def test_ejercicio05(self):
        lista = crear_lista_nodos_departamentos()

        cabeza: Nodito[Departamento] = nulo
        cabeza = agregar_nodo_en_posicion(nulo, obtener_nodo_pos(lista, 0).informacion, 0)
        self.assertNoEsNulo(cabeza)
        self.assertEsNulo(cabeza.sig)
        self.assertEqual("Amazonas", cabeza.informacion.nombre)

        actual: Nodito[Departamento] = cabeza
        for i in range(1, 20):
            nod1 = crear_nodo_departamento(obtener_nodo_pos(lista, i).informacion)
            actual.sig = nod1
            actual = nod1

        cabeza = agregar_nodo_en_posicion(cabeza, obtener_nodo_pos(lista, 32).informacion, 0)
        self.assertNoEsNulo(cabeza)
        self.assertNoEsNulo(cabeza.sig)
        self.assertEqual("Vichada", cabeza.informacion.nombre)

        actual = cabeza.sig
        i = 0
        while actual.no_es_nulo:
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = agregar_nodo_en_posicion(cabeza, obtener_nodo_pos(lista, 31).informacion, 40)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        while actual.sig != nulo:
            actual = actual.sig
        self.assertEqual("Vaupés", actual.informacion.nombre)

        cabeza = nulo
        for i in range(20):
            cabeza = agregar_nodo_en_posicion(cabeza, obtener_nodo_pos(lista, i).informacion, i)
            self.assertNoEsNulo(cabeza)

        actual = cabeza
        i = 0
        while actual != nulo:
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = agregar_nodo_en_posicion(cabeza, obtener_nodo_pos(lista, 30).informacion, 10)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        for i in range(10):
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
        self.assertNoEsNulo(actual)
        self.assertEqual(obtener_nodo_pos(lista, 30).informacion.nombre, actual.informacion.nombre)
        i = 10
        actual = actual.sig
        while actual != nulo:
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1


        print("Prueba superada 👍🏼")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio05'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 6: eliminar el primer nodo de la lista
#
# Para eliminar un nodo de la lista vamos a utilizar el siguiente algoritmo:
#
# ```
# si la cabeza no nula entonces
#     avanzar la cabeza al siguiente
# fin-si
# retornar la cabeza
# ```
#
# Traslade ese algoritmo a Python:

# %%
from ean import Departamento, Nodito, nulo

# Ejercicio 6: eliminar el primer nodo

def eliminar_primer_nodo(cabeza: Nodito[Departamento]) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del ejercicio 6

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo

# Prueba de hallar_imc
class TestEjercicio6(unittest.TestCase):
    def assertEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertTrue(nodo1.es_nulo)

    def assertNoEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertFalse(nodo1.es_nulo)

    def test_ejercicio6(self):
        cabeza = crear_lista_nodos_departamentos()
        lista = crear_lista_nodos_departamentos()
        cabeza = eliminar_primer_nodo(cabeza)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        i = 1
        while actual != nulo:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = eliminar_primer_nodo(cabeza)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        i = 2
        while actual != nulo:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = crear_nodo_departamento(obtener_nodo_pos(lista, 1).informacion)
        self.assertNoEsNulo(cabeza)
        cabeza = eliminar_primer_nodo(cabeza)
        self.assertEsNulo(cabeza)

        print("Prueba superada 👍🏼")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio6'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 7: Eliminar nodo en una posición
#
# Ahora vamos a eliminar un nodo ubicado en una posición dada de la lista. Tenga en cuenta
# que las posiciones inician en cero. El algoritmo para eliminar un nodo en la
# posición dada, es el siguiente:
#
# ```
# si la posicion es cero entonces
#   retornar eliminar el primer nodo
# sino
#   haga actual igual a la cabeza
#   haga i igual a 1
#   mientras que i sea inferior a la posición y el siguiente del actual no sea nulo
#     avanzar actual al siguiente
#     sumarle uno a i
#   fin-mientras-que
#   si el siguiente del actual no es nulo:
#     haga al siguiente del actual igual al siguiente del siguiente del actual
#   fin-si
#   retornar la cabeza
# fin-si
#
# ```
#
# Traduzca este algoritmo a Python.

# %%
from ean import Departamento, Nodito, nulo

# Ejercicio 7: eliminar un nodo

def eliminar_nodo_en_posicion(cabeza: Nodito[Departamento], posicion: int) -> Nodito[Departamento]:
    pass

# %% [markdown]
# ---
#
# Prueba del Ejercicio 7

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo

# Prueba de hallar_imc
class TestEjercicio7(unittest.TestCase):
    def assertEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertTrue(nodo1.es_nulo)

    def assertNoEsNulo(self, nodo1 : Nodito[Departamento]):
        self.assertFalse(nodo1.es_nulo)

    def test_ejercicio7(self):
        lista = crear_lista_nodos_departamentos()
        cabeza = crear_lista_nodos_departamentos()

        cabeza = eliminar_nodo_en_posicion(cabeza=cabeza, posicion=0)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        i = 1
        while actual != nulo:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = crear_lista_nodos_departamentos()
        cabeza = eliminar_nodo_en_posicion(cabeza, 15)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        i = 0
        while i < 15:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1
        i = 16
        while actual != nulo:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        cabeza = crear_lista_nodos_departamentos()
        cabeza = eliminar_nodo_en_posicion(cabeza, 32)
        self.assertNoEsNulo(cabeza)
        actual = cabeza
        i = 0
        while actual != nulo:
            self.assertNoEsNulo(actual)
            self.assertEqual(actual.informacion.nombre, obtener_nodo_pos(lista, i).informacion.nombre)
            actual = actual.sig
            i = i + 1

        self.assertEqual(32, i)
        print("Prueba Superada 👍🏼")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio7'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 8: Contar el número de nodos
#
# En este ejercicio debemos recorrer la lista, contando los nodos que hace parte de la lista. Su misión es escribir una función externa `tam_lista` que reciba un único parámetro llamado `cab` que se trata de la cabeza a una lista de nodos sencillamente encadenados de departamentos y retornará el número de nodos en la lista.

# %%
from ean import Departamento, Nodito, nulo

# Ejercicio 8: obtener el número de nodos de la lista

# %% [markdown]
# ---
#
# Prueba del Ejercicio 8

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo, obtener_nodo_pos

# Prueba de hallar_imc
class TestEjercicio8(unittest.TestCase):
    def deptos(self, pos : int) -> Departamento:
        return obtener_nodo_pos(self.lista, pos).informacion

    def __crear_lista(self, n: int) -> Nodito[Departamento]:
        cabeza = nulo
        actual = nulo
        for i in range(n):
            if cabeza is nulo:
                cabeza = Nodito[Departamento](self.deptos(i))
                actual = cabeza
            else:
                actual.sig = Nodito[Departamento](self.deptos(i))
                actual = actual.sig
        return cabeza
    
    def test_ejercicio8(self):
        self.cabeza = nulo
        self.assertEqual(0, tam_lista(cab=self.cabeza))
        
        self.lista = crear_lista_nodos_departamentos()
        self.assertEqual(33, tam_lista(cab=self.lista))

        self.cabeza = self.__crear_lista(15)
        self.assertEqual(15, tam_lista(self.cabeza))

        self.cabeza = self.__crear_lista(1)
        self.assertEqual(1, tam_lista(self.cabeza))

        print("Prueba superada 👍🏽")


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio8'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# # Ejercicio 9: Porcentajes
#
# Escribir una función externa llamada `ejercicio09` que reciba dos datos de entrada: el primero se llama `cab` y es la cabeza de una lista de nodos sencillamente encadenados de departamentos; el segundo parámetro
# es un `str` y se llama `region`. La función debe retornar el porcentaje de los departamentos de la lista
# que pertenecen a la región que se pasa como parámetro.

# %%
from ean import Departamento, Nodito, nulo

# Ejercicio 9

# %% [markdown]
# ---
#
# Prueba del Ejercicio 9

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos

# Prueba de hallar_imc
class TestEjercicio9(unittest.TestCase):

    def test_ejercicio9(self):
        lista = crear_lista_nodos_departamentos()

        self.assertAlmostEqual(18.1818, ejercicio09(cab=lista, region="Amazonía"), places=4)
        self.assertAlmostEqual(33.3333, ejercicio09(lista, "Andina"), places=4)
        self.assertAlmostEqual(24.2424, ejercicio09(lista, "Caribe"), places=4)
        self.assertAlmostEqual(12.1212, ejercicio09(lista, "Pacífico"), places=4)


# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio9'], verbosity=2, exit=False);
print('Prueba superada 👍🏼')

# %% [markdown]
# ---
#
# ### Ejercicio 10: Sumas
#
# Escriba una función externa llamada `ejercicio10` que reciba tres parámetros: el primer parámetro se llama `cab` y es la cabeza de una lista de noditos sencillamente encadenados de departamentos; el segundo parámetro es un
# `str` llamado `region` y el tercer parámetro se llama `letra` y es un `str`. La función debe retornar la suma de la población de los departamentos que pertenecen a la región que se recibe como parámetro y que la primera letra del nombre es igual a la letra que se recibe como parámetro y tienen más de 50 años de haber sido creados.

# %%
from ean import Departamento, Nodito, nulo

# Ejercicio 10

# %% [markdown]
# ---
#
# Prueba del ejercicio 10

# %%
import unittest
from ean import Departamento, crear_lista_nodos_departamentos, Nodito, nulo

# Prueba de hallar_imc
class TestEjercicio10(unittest.TestCase):

    def test_ejercicio10(self):
        cabeza = crear_lista_nodos_departamentos()

        self.assertEqual(9_151_627, ejercicio10(cab=cabeza, region='Andina', letra='B'))
        self.assertEqual(3_582_373, ejercicio10(cabeza, 'Andina', 'C'))
        self.assertEqual(2_662_154, ejercicio10(cabeza, 'Caribe', 'C'))
        self.assertEqual(2_403_027, ejercicio10(cabeza, 'Caribe', 'A'))
        self.assertEqual(0, ejercicio10(cab=cabeza, region='Caribe', letra='D'))
        

# --------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio10'], verbosity=2, exit=False);
print('Prueba superada 👍🏼')
